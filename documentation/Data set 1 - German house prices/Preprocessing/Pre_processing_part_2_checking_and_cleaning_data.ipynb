# %% [markdown]
# ## Preprocessing of data, Part 2 - checking and cleaning dataset

# %% [markdown]
# In this notebook will we check the data in the csv-file we created in part 1, to see if there is anything we have to pay extra attention to when we start with part 3 (remove or replace missing data)

# %% [markdown]
# ### Import libraries and dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Uses csv-file with unwanted columns removed
df = pd.read_csv('germany_housing_data_part1_with_unwanted_columns_removed.csv')
df.head(10)
# Out:
#    Living_space     Lot  Rooms  Bedrooms  Bathrooms  Floors  Year_built  \
# 0        106.00   229.0    5.5       3.0        1.0     2.0      2005.0
# 1        140.93   517.0    6.0       3.0        2.0     NaN      1994.0
# 2        162.89    82.0    5.0       3.0        2.0     4.0      2013.0
# 3        140.00   814.0    4.0       NaN        2.0     2.0      1900.0
# 4        115.00   244.0    4.5       2.0        1.0     NaN      1968.0
# 5        310.00   860.0    8.0       NaN        NaN     3.0      1969.0
# 6        502.00  5300.0   13.0       NaN        4.0     NaN      2004.0
# 7        263.00   406.0   10.0       NaN        NaN     3.0      1989.0
# 8        227.00   973.0   10.0       4.0        4.0     2.0      1809.0
# 9        787.00   933.0   30.0       NaN        NaN     3.0      1920.0
#
#    Year_renovated  Garages    Condition          Heating  \
# 0             NaN      2.0   modernized  central heating
# 1             NaN      7.0   modernized    stove heating
# 2             NaN      1.0  dilapidated    stove heating
# 3          2000.0      1.0  fixer-upper  central heating
# 4          2019.0      1.0  refurbished  central heating
# 5             NaN      2.0   maintained              NaN
# 6             NaN      7.0  dilapidated    stove heating
# 7             NaN      2.0   modernized    stove heating
# 8          2015.0      8.0   modernized  central heating
# 9             NaN     12.0   modernized    stove heating
#
#                           Energy_source              State   Garagetype  \
# 0                                   gas  Baden-Württemberg  Parking lot
# 1                                   NaN  Baden-Württemberg  Parking lot
# 2  other combinations of energy sources  Baden-Württemberg       Garage
# 3                           electricity  Baden-Württemberg       Garage
# 4                                   oil  Baden-Württemberg       Garage
# 5                                   oil  Baden-Württemberg       Garage
# 6  other combinations of energy sources  Baden-Württemberg  Parking lot
# 7                                   gas  Baden-Württemberg       Garage
# 8                           electricity  Baden-Württemberg  Parking lot
# 9  other combinations of energy sources  Baden-Württemberg  Parking lot
#
#                 Type      Price
# 0  Multiple dwelling   498000.0
# 1  Mid-terrace house   495000.0
# 2          Farmhouse   749000.0
# 3          Farmhouse   259000.0
# 4  Multiple dwelling   469000.0
# 5  Mid-terrace house  1400000.0
# 6             Duplex  3500000.0
# 7             Duplex   630000.0
# 8             Duplex   364000.0
# 9             Duplex  1900000.0

# %% [markdown]
# ### Checking the data

# %% [markdown]
# We start with an overview of our data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10552 entries, 0 to 10551
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Living_space    10552 non-null  float64
#  1   Lot             10552 non-null  float64
#  2   Rooms           10552 non-null  float64
#  3   Bedrooms        6878 non-null   float64
#  4   Bathrooms       8751 non-null   float64
#  5   Floors          7888 non-null   float64
#  6   Year_built      9858 non-null   float64
#  7   Year_renovated  5349 non-null   float64
#  8   Garages         8592 non-null   float64
#  9   Condition       10229 non-null  object
#  10  Heating         9968 non-null   object
#  11  Energy_source   9325 non-null   object
#  12  State           10551 non-null  object
#  13  Garagetype      8592 non-null   object
#  14  Type            10150 non-null  object
#  15  Price           10552 non-null  float64
# dtypes: float64(10), object(6)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#        Living_space            Lot         Rooms     Bedrooms    Bathrooms  \
# count  10552.000000   10552.000000  10552.000000  6878.000000  8751.000000
# mean     216.721008    1491.659004      7.388978     4.169817     2.308993
# std      172.421321    8582.361675      5.378126     2.577169     1.742330
# min        0.000000       0.000000      1.000000     0.000000     0.000000
# 25%      130.000000     370.000000      5.000000     3.000000     1.000000
# 50%      176.775000     656.500000      6.000000     4.000000     2.000000
# 75%      250.000000    1047.000000      8.000000     5.000000     3.000000
# max     5600.000000  547087.000000    170.000000    61.000000    44.000000
#
#             Floors   Year_built  Year_renovated      Garages         Price
# count  7888.000000  9858.000000     5349.000000  8592.000000  1.055200e+04
# mean      2.283976  1958.821465     2010.706300     2.698673  5.566851e+05
# std       0.821288    55.958072       10.548651     3.195068  6.087410e+05
# min       0.000000  1300.000000     1900.000000     1.000000  0.000000e+00
# 25%       2.000000  1935.000000     2006.000000     1.000000  2.500000e+05
# 50%       2.000000  1971.000000     2015.000000     2.000000  4.052150e+05
# 75%       3.000000  1996.000000     2018.000000     3.000000  6.550000e+05
# max      13.000000  2022.000000     2206.000000    70.000000  1.300000e+07

# %% [markdown]
# We can see that there is at least one faulty value in 'Year_renovated', since the max value states that a house has been renovated in year 2206.
#
# But let us start in the beginning.

# %% [markdown]
# #### Rooms vs Bedrooms

# %% [markdown]
# The definition of Rooms is rooms with daylight, not counting kitchen or bathrooms.
#
# We do a quick check to see if we have any cases where number of Bedrooms are larger the number of Rooms.

# %%
num_of_rooms = df['Rooms'].values
num_of_bedrooms = df['Bedrooms'].values

# %%
strange_rows = 0
index_to_check = []
for i in range(len(num_of_rooms)):
    if num_of_bedrooms[i] > num_of_rooms[i]:
        strange_rows += 1
        index_to_check.append(i)
print(strange_rows)
print(index_to_check)
# Out:
# 14
# [441, 458, 677, 778, 810, 997, 1322, 1758, 6564, 6890, 6960, 8584, 8796, 10239]

# %%
df.loc[index_to_check]
# Out:
#        Living_space     Lot  Rooms  Bedrooms  Bathrooms  Floors  Year_built  \
# 441          150.00   498.0    5.0       6.0        1.0     3.0      1936.0
# 458          628.00   646.0    5.0       6.0        8.0     3.0      1715.0
# 677          100.00   105.0    2.5       3.0        1.0     3.0      1923.0
# 778          157.00   661.0    3.0       4.0        3.0     3.0      1998.0
# 810          500.00  2228.0   14.0      15.0        3.0     3.0         NaN
# 997          356.00  3550.0    2.5       6.0        4.0     4.0      1937.0
# 1322         528.56   800.0    6.0      12.0        6.0     3.0      1969.0
# 1758         611.00   500.0   19.0      20.0        6.0     4.0      1750.0
# 6564         355.12  3912.0    5.5       8.0        5.0     NaN      1964.0
# 6890         150.00   700.0    2.0       4.0        4.0     3.0      1948.0
# 6960         440.00  1600.0    3.0       4.0        3.0     2.0      1895.0
# 8584         200.00   115.0    5.0       7.0        1.0     NaN      1900.0
# 8796         145.00  1800.0    3.0       4.0        2.0     2.0      1982.0
# 10239        178.00  3525.0    1.0       5.0        2.0     2.0      1906.0
#
#        Year_renovated  Garages       Condition              Heating  \
# 441               NaN      NaN      modernized      central heating
# 458            2017.0      6.0      modernized  wood-pellet heating
# 677               NaN      1.0     refurbished   underfloor heating
# 778            2015.0      3.0      modernized                  NaN
# 810               NaN      NaN      maintained        stove heating
# 997               NaN      2.0     refurbished        stove heating
# 1322           2020.0      6.0     dilapidated                  NaN
# 1758           2019.0      5.0     fixer-upper        stove heating
# 6564              NaN      4.0      modernized        stove heating
# 6890           2019.0      3.0  by arrangement        stove heating
# 6960           2017.0     14.0  by arrangement        stove heating
# 8584           2016.0      NaN      modernized            heat pump
# 8796           2015.0      5.0      modernized                  NaN
# 10239          2010.0      NaN     fixer-upper        stove heating
#
#                               Energy_source                State  \
# 441                                     gas    Baden-Württemberg
# 458                             electricity    Baden-Württemberg
# 677                                     oil    Baden-Württemberg
# 778                                     NaN    Baden-Württemberg
# 810                                     oil    Baden-Württemberg
# 997                                     gas    Baden-Württemberg
# 1322                                    oil               Bayern
# 1758                                    gas               Bayern
# 6564                                    gas  Nordrhein-Westfalen
# 6890                                    gas  Nordrhein-Westfalen
# 6960                                    oil  Nordrhein-Westfalen
# 8584                                    gas      Rheinland-Pfalz
# 8796                                    oil             Saarland
# 10239  other combinations of energy sources   Schleswig-Holstein
#
#                     Garagetype               Type      Price
# 441                        NaN  Mid-terrace house   799000.0
# 458                Parking lot             Duplex   645000.0
# 677        Outside parking lot  Mid-terrace house    97500.0
# 778                     Garage             Duplex   529000.0
# 810                        NaN           Bungalow   270000.0
# 997        Outside parking lot              Villa  7950000.0
# 1322   Underground parking lot             Duplex  2700000.0
# 1758       Outside parking lot             Duplex   799900.0
# 6564                    Garage             Duplex  1300000.0
# 6890       Outside parking lot             Duplex   689030.0
# 6960       Outside parking lot             Duplex   256010.0
# 8584                       NaN  Mid-terrace house   289000.0
# 8796       Outside parking lot  Mid-terrace house   350000.0
# 10239                      NaN             Duplex   390000.0

# %% [markdown]
# Two ways to deal with this:
# * Delete the rows in question
# * Replace the value for 'Bedrooms' with NaN and deal with this in part 3, with the rest of the missing data.
#
# Do not forget to make the same test in part 3C when we impute values.

# %% [markdown]
# #### Year_built

# %% [markdown]
# We can see that there is houses with a 'Year_built' value that is bigger than 2020. But the max value is 2022 - so it is probably not an error but rather prediction on new construction.

# %%
df['Year_built'].describe()
# Out:
# count    9858.000000
# mean     1958.821465
# std        55.958072
# min      1300.000000
# 25%      1935.000000
# 50%      1971.000000
# 75%      1996.000000
# max      2022.000000
# Name: Year_built, dtype: float64

# %% [markdown]
# We check how many we are talking about...

# %%
building_years = df['Year_built'].values

# %%
new =0
new_buildings = []
index =[]
for i in range(len(building_years)):
    if building_years[i] > 0:
        if building_years[i] > 2020:
            new += 1
            new_buildings.append(building_years[i])
            index.append(i)
print(str(new) + ' houses has not been completed in 2020.')
# Out:
# 66 houses has not been completed in 2020.

# %%
print(str(new_buildings.count(2021)) + ' are rapported to be completed in 2021.')
print(str(new_buildings.count(2022)) + ' are rapported to be completed in 2022.')
# Out:
# 61 are rapported to be completed in 2021.
# 5 are rapported to be completed in 2022.

# %%
#df.loc[index]

# %% [markdown]
# We have decided to accept this.

# %% [markdown]
# #### Year_renovated

# %% [markdown]
# As seen again below there is a max value of 2206. That has to be an error in the data.

# %%
df['Year_renovated'].describe()
# Out:
# count    5349.000000
# mean     2010.706300
# std        10.548651
# min      1900.000000
# 25%      2006.000000
# 50%      2015.000000
# 75%      2018.000000
# max      2206.000000
# Name: Year_renovated, dtype: float64

# %% [markdown]
# We choose to replace all value bigger then 2021 with a missing value.

# %%
y_r = df['Year_renovated'].values

for i in range(len(y_r)):
    if y_r[i] > 2021.0:
        y_r[i] = np.nan

# %% [markdown]
# A final check to see that it is done.

# %%
df['Year_renovated'].describe()
# Out:
# count    5346.000000
# mean     2010.664796
# std        10.204488
# min      1900.000000
# 25%      2006.000000
# 50%      2015.000000
# 75%      2018.000000
# max      2020.000000
# Name: Year_renovated, dtype: float64

# %% [markdown]
# #### Year_built vs Year_renovated

# %% [markdown]
# Next part to check is the relationship 'Year_built' and 'Year_renovated'.
#
# A house can not be renovated prior than it was originally built.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10552 entries, 0 to 10551
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Living_space    10552 non-null  float64
#  1   Lot             10552 non-null  float64
#  2   Rooms           10552 non-null  float64
#  3   Bedrooms        6878 non-null   float64
#  4   Bathrooms       8751 non-null   float64
#  5   Floors          7888 non-null   float64
#  6   Year_built      9858 non-null   float64
#  7   Year_renovated  5346 non-null   float64
#  8   Garages         8592 non-null   float64
#  9   Condition       10229 non-null  object
#  10  Heating         9968 non-null   object
#  11  Energy_source   9325 non-null   object
#  12  State           10551 non-null  object
#  13  Garagetype      8592 non-null   object
#  14  Type            10150 non-null  object
#  15  Price           10552 non-null  float64
# dtypes: float64(10), object(6)
# memory usage: 1.3+ MB

# %%
year_r = df['Year_renovated'].values
year_b = df['Year_built'].values

# %%
len(year_r)
# Out:
# 10552

# %%
strange_rows_2 = 0
index_to_check_2 = []
for i in range(len(year_r)):
    if year_b[i] > year_r[i]:
        strange_rows_2 += 1
        index_to_check_2.append(i)
print(strange_rows_2)
print(index_to_check_2)
# Out:
# 11
# [972, 3367, 3978, 4740, 6842, 7459, 7851, 8135, 8684, 10361, 10379]

# %%
df.loc[index_to_check_2]
# Out:
#        Living_space     Lot  Rooms  Bedrooms  Bathrooms  Floors  Year_built  \
# 972          246.00   443.0   10.0       5.0        4.0     3.0      2019.0
# 3367         120.00   694.0    6.0       4.0        1.0     2.0      2006.0
# 3978         135.17   655.0    5.0       4.0        2.0     2.0      2020.0
# 4740         314.00  9188.0    7.0       5.0        3.0     2.0      2015.0
# 6842         145.00   800.0    6.0       5.0        1.0     3.0      2012.0
# 7459         280.00   911.0   10.0       8.0        3.0     4.0      2013.0
# 7851         131.00   782.0    5.0       4.0        2.0     2.0      2021.0
# 8135         113.00   136.0    5.0       3.0        1.0     3.0      1940.0
# 8684         280.00   620.0    8.0       5.0        3.0     2.0      2016.0
# 10361        180.00   827.0    6.0       4.0        2.0     1.0      2004.0
# 10379        289.00   850.0    6.0       NaN        4.0     2.0      2019.0
#
#        Year_renovated  Garages                             Condition  \
# 972            2000.0      3.0                            maintained
# 3367           2004.0      1.0                            modernized
# 3978           2019.0      2.0                                   NaN
# 4740           1998.0      1.0                           fixer-upper
# 6842           2000.0      1.0                            modernized
# 7459           2010.0      2.0                             renovated
# 7851           2020.0      4.0                                   NaN
# 8135           1917.0      NaN                             renovated
# 8684           2015.0      NaN                            modernized
# 10361          1974.0      2.0                             renovated
# 10379          2018.0      2.0  first occupation after refurbishment
#
#              Heating            Energy_source                   State  \
# 972    stove heating                      oil       Baden-Württemberg
# 3367   stove heating                      gas                  Bremen
# 3978   stove heating               solar, gas                  Hessen
# 4740       heat pump                      gas  Mecklenburg-Vorpommern
# 6842   stove heating                      gas     Nordrhein-Westfalen
# 7459   stove heating  liquefied petroleum gas     Nordrhein-Westfalen
# 7851   stove heating              electricity         Rheinland-Pfalz
# 8135   stove heating                      oil         Rheinland-Pfalz
# 8684   stove heating                      gas         Rheinland-Pfalz
# 10361      heat pump                      gas      Schleswig-Holstein
# 10379  stove heating                      gas      Schleswig-Holstein
#
#                 Garagetype               Type      Price
# 972             Duplex lot             Duplex   770000.0
# 3367                Garage  Mid-terrace house   729000.0
# 3978   Outside parking lot  Mid-terrace house   471000.0
# 4740                Garage  Mid-terrace house   765000.0
# 6842                Garage  Mid-terrace house   379000.0
# 7459   Outside parking lot  Mid-terrace house   449000.0
# 7851           Parking lot  Mid-terrace house   382500.0
# 8135                   NaN    Single dwelling   189000.0
# 8684                   NaN             Duplex  1250000.0
# 10361          Parking lot                NaN   650000.0
# 10379  Outside parking lot    Single dwelling  5575000.0

# %% [markdown]
# Three ways to deal with this:
# * Delete the rows in question
# * Replace the values with NaN and deal with this in part 3, with the rest of the missing data.
# * Change place on the values in the two columns

# %% [markdown]
# ### Removing rows

# %% [markdown]
# We choose to remove the rows in both cases above. And we did it all at once.

# %%
rows_to_drop = index_to_check + index_to_check_2
print(len(rows_to_drop))
rows_to_drop
# Out:
# 25
# [441,
#  458,
#  677,
#  778,
#  810,
#  997,
#  1322,
#  1758,
#  6564,
#  6890,
#  6960,
#  8584,
#  8796,
#  10239,
#  972,
#  3367,
#  3978,
#  4740,
#  6842,
#  7459,
#  7851,
#  8135,
#  8684,
#  10361,
#  10379]

# %%
df.drop(rows_to_drop, inplace=True)

# %% [markdown]
# A quick check...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10527 entries, 0 to 10551
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Living_space    10527 non-null  float64
#  1   Lot             10527 non-null  float64
#  2   Rooms           10527 non-null  float64
#  3   Bedrooms        6854 non-null   float64
#  4   Bathrooms       8726 non-null   float64
#  5   Floors          7865 non-null   float64
#  6   Year_built      9834 non-null   float64
#  7   Year_renovated  5326 non-null   float64
#  8   Garages         8573 non-null   float64
#  9   Condition       10206 non-null  object
#  10  Heating         9946 non-null   object
#  11  Energy_source   9301 non-null   object
#  12  State           10526 non-null  object
#  13  Garagetype      8573 non-null   object
#  14  Type            10126 non-null  object
#  15  Price           10527 non-null  float64
# dtypes: float64(10), object(6)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Saving the changes

# %% [markdown]
# We save our changes to a new csv-file for the next step in our preprocessing of data

# %%
df.to_csv('germany_housing_data_part2_after_cleaning.csv', index=False)
